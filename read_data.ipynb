# %%
import polars as pl

df = pl.read_csv("D:\\DEPI\\Project\\credit-risk-analysis\\Data\\bureau.csv")
df.head()
# Out:
# shape: (5, 17)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ SK_ID_CUR ┆ SK_ID_BUR ┆ CREDIT_AC ┆ CREDIT_CU ┆ … ┆ AMT_CREDI ┆ CREDIT_TY ┆ DAYS_CRED ┆ AMT_ANNU │
# │ R         ┆ EAU       ┆ TIVE      ┆ RRENCY    ┆   ┆ T_SUM_OVE ┆ PE        ┆ IT_UPDATE ┆ ITY      │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ RDUE      ┆ ---       ┆ ---       ┆ ---      │
# │ i64       ┆ i64       ┆ str       ┆ str       ┆   ┆ ---       ┆ str       ┆ i64       ┆ str      │
# │           ┆           ┆           ┆           ┆   ┆ f64       ┆           ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 215354    ┆ 5714462   ┆ Closed    ┆ currency  ┆ … ┆ 0.0       ┆ Consumer  ┆ -131      ┆ null     │
# │           ┆           ┆           ┆ 1         ┆   ┆           ┆ credit    ┆           ┆          │
# ...
